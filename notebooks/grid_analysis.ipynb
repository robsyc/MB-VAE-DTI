# %%
from resolve import *
# Out:
# Setting working directory to: /home/robsyc/Desktop/thesis/MB-VAE-DTI

# %%
from mb_vae_dti.validating.analysis import *

df = load_gridsearch_results("notebooks/results/summer/version1/baseline_davis_cold")

if "metadata.data.provenance_cols" in df.columns:
    df["metadata.data.provenance_cols"] = df["metadata.data.provenance_cols"].apply(lambda x: x[0])
if "metadata.data.drug_features" in df.columns:
    df = df.drop(columns=["metadata.data.drug_features", "metadata.data.target_features"])

df
# Out:
# 2025-07-20 21:28:51,089 - mb_vae_dti.validating.analysis - INFO - Successfully loaded 144 results with 40 columns
#                              experiment_name  best_val_loss  best_epoch  \
# 0    baseline_DAVIS_cold_b01c0014_1752835623       0.649304          29
# 1    baseline_DAVIS_cold_b00c0022_1752839977       1.146805          53
# 2    baseline_DAVIS_cold_b00c0043_1752850522       1.879613          34
# 3    baseline_DAVIS_cold_b02c0002_1752832262       0.739543          29
# 4    baseline_DAVIS_cold_b02c0027_1752843448       0.642804          30
# ..                                       ...            ...         ...
# 139  baseline_DAVIS_cold_b02c0003_1752832371       0.761007          45
# 140  baseline_DAVIS_cold_b02c0016_1752837575       0.993746          27
# 141  baseline_DAVIS_cold_b00c0003_1752832930       0.702523          14
# 142  baseline_DAVIS_cold_b02c0028_1752843869       0.798631          42
# 143  baseline_DAVIS_cold_b00c0030_1752844076       1.259224          59
#
#      trainable_params     timestamp  metadata.training.max_epochs  \
# 0             2183936  1.752836e+09                           100
# 1             1721344  1.752840e+09                           100
# 2             5014528  1.752851e+09                           100
# 3             3960832  1.752832e+09                           100
# 4             5144576  1.752844e+09                           100
# ..                ...           ...                           ...
# 139           5012992  1.752833e+09                           100
# 140           1522688  1.752838e+09                           100
# 141           5012992  1.752833e+09                           100
# 142           2117888  1.752844e+09                           100
# 143           6594048  1.752845e+09                           100
#
#      metadata.training.early_stopping_patience metadata.training.scheduler  \
# 0                                           10                   one_cycle
# 1                                           10                   one_cycle
# 2                                           10                   one_cycle
# 3                                           10                   one_cycle
# 4                                           10                   one_cycle
# ..                                         ...                         ...
# 139                                         10                   one_cycle
# 140                                         10                   one_cycle
# 141                                         10                   one_cycle
# 142                                         10                   one_cycle
# 143                                         10                   one_cycle
#
#      metadata.training.learning_rate  metadata.data.load_in_memory  ...  \
# 0                             0.0010                          True  ...
# 1                             0.0001                          True  ...
# 2                             0.0005                          True  ...
# 3                             0.0010                          True  ...
# 4                             0.0010                          True  ...
# ..                               ...                           ...  ...
# 139                           0.0001                          True  ...
# 140                           0.0001                          True  ...
# 141                           0.0010                          True  ...
# 142                           0.0010                          True  ...
# 143                           0.0005                          True  ...
#
#     metrics.val/ci metrics.val/mse metrics.val/pearson  metrics.val/r2  \
# 0         0.707990        0.710287            0.435369        0.101036
# 1         0.568964        1.331479            0.173217       -0.685154
# 2         0.507338        2.510612            0.040745       -2.177493
# 3         0.607501        0.816275            0.251758       -0.033099
# 4         0.597679        0.788492            0.270564        0.002058
# ..             ...             ...                 ...             ...
# 139       0.607833        0.829065            0.246960       -0.049294
# 140       0.443792        1.198562           -0.122086       -0.516930
# 141       0.576954        0.922572            0.189366       -0.167639
# 142       0.528844        0.934391            0.122198       -0.182589
# 143       0.595479        1.443617            0.210530       -0.827074
#
#     metrics.val/rmse timing.total_training_time timing.avg_time_per_epoch  \
# 0           1.703194                 647.501592                 16.187540
# 1           3.023119                 233.083112                  3.641924
# 2           4.272798                 163.200549                  3.626679
# 3           1.919001                  99.397365                  2.484934
# 4           1.194973                 410.978220                 10.023859
# ..               ...                        ...                       ...
# 139         2.162242                 543.642326                  9.707899
# 140         2.528209                  95.577448                  2.515196
# 141         1.269132                 241.982054                  9.679282
# 142         1.897164                 244.647662                  4.615994
# 143         3.547050                 593.548760                  8.479268
#
#     timing.total_epochs  timing.min_epoch_time timing.max_epoch_time
# 0                    40              15.926162             16.179187
# 1                    64               3.446389              3.782759
# 2                    45               3.449837              3.643241
# 3                    40               2.288169              2.533332
# 4                    41               9.601018             10.005024
# ..                  ...                    ...                   ...
# 139                  56               9.030612              9.831343
# 140                  38               2.298256              2.836979
# 141                  25               9.501238              9.592737
# 142                  53               4.312968              4.588890
# 143                  70               7.921215              8.573899
#
# [144 rows x 40 columns]

# %%
varying_attrs = get_varying_attributes(df)
varying_attrs.remove('metadata.logging.experiment_name')
varying_attrs.extend(["best_val_loss", 'best_epoch', 'trainable_params', "timing.total_training_time"])
varying_attrs
# Out:
# 2025-07-20 21:28:52,145 - mb_vae_dti.validating.analysis - INFO - Found 7 varying attributes: ['metadata.training.learning_rate', 'metadata.data.batch_size', 'metadata.logging.experiment_name', 'metadata.model.encoder_kwargs.hidden_dim', 'metadata.model.encoder_kwargs.output_dim', 'metadata.model.encoder_kwargs.n_layers', 'metadata.model.encoder_type']
# ['metadata.training.learning_rate',
#  'metadata.data.batch_size',
#  'metadata.model.encoder_kwargs.hidden_dim',
#  'metadata.model.encoder_kwargs.output_dim',
#  'metadata.model.encoder_kwargs.n_layers',
#  'metadata.model.encoder_type',
#  'best_val_loss',
#  'best_epoch',
#  'trainable_params',
#  'timing.total_training_time']

# %%
subdf = get_top_performers(df, n_top=50)[varying_attrs]
# for each columns, rename the column by splitting the column name by "." and taking the last element
subdf.columns = subdf.columns.str.split(".").str[-1]
print(df["timing.total_training_time"].mean())
subdf
# Out:
# 383.1864097234276
#      learning_rate  batch_size  hidden_dim  output_dim  n_layers encoder_type  \
# 54          0.0010          32         256         768         2       resnet
# 105         0.0005          32         256         768         2       resnet
# 106         0.0010          16         256         768         2       resnet
# 49          0.0010          64         256         768         2       resnet
# 98          0.0005          16         256         768         2       resnet
# 117         0.0005          16         128         768         3  transformer
# 39          0.0010          32         256         768         3       resnet
# 16          0.0010          32         256         512         3       resnet
# 130         0.0005          16         128         768         3       resnet
# 52          0.0010          32         128         768         3  transformer
# 5           0.0005          32         256         768         3       resnet
# 4           0.0010          16         256         768         3       resnet
# 0           0.0010          16         128         768         3  transformer
# 22          0.0010          32         128         768         3       resnet
# 28          0.0010          64         128         512         2       resnet
# 26          0.0005          64         256         768         2       resnet
# 42          0.0005          32         256         512         3       resnet
# 85          0.0010          64         256         768         3       resnet
# 41          0.0005          32         128         768         3       resnet
# 18          0.0010          64         128         768         3  transformer
# 88          0.0005          32         128         512         2       resnet
# 51          0.0010          16         128         512         2       resnet
# 132         0.0005          64         128         768         3       resnet
# 134         0.0005          16         128         768         2  transformer
# 7           0.0005          32         128         512         3       resnet
# 79          0.0010          32         128         768         2  transformer
# 86          0.0005          32         128         768         3  transformer
# 129         0.0010          64         256         512         3       resnet
# 80          0.0005          64         256         768         3       resnet
# 56          0.0010          16         128         512         3       resnet
# 118         0.0005          64         128         512         2       resnet
# 27          0.0010          64         128         512         3       resnet
# 92          0.0005          16         128         512         2       resnet
# 123         0.0005          64         256         512         3       resnet
# 113         0.0001          16         256         768         2       resnet
# 77          0.0005          16         256         768         3       resnet
# 67          0.0010          16         128         768         2  transformer
# 115         0.0010          32         128         512         2       resnet
# 131         0.0010          32         128         512         3       resnet
# 10          0.0005          32         128         768         2  transformer
# 65          0.0010          64         128         768         2  transformer
# 107         0.0005          64         128         768         3  transformer
# 141         0.0010          16         256         512         3       resnet
# 29          0.0005          64         128         512         3       resnet
# 72          0.0001          32         256         768         2       resnet
# 89          0.0010          16         128         768         3       resnet
# 12          0.0005          16         128         512         3       resnet
# 119         0.0005          16         256         512         2       resnet
# 108         0.0005          64         256         512         2       resnet
# 83          0.0001          16         128         512         2       resnet
#
#      best_val_loss  best_epoch  trainable_params  total_training_time
# 54        0.560911          30           4092416           187.758013
# 105       0.574381          30           4092416           179.755320
# 106       0.589933          29           4092416           347.738762
# 49        0.591508          21           4092416            82.700069
# 98        0.600209          59           4092416           624.819655
# 117       0.622744          45           2183936           958.166862
# 39        0.629301          31           5144576           225.338626
# 16        0.630984          43           5012992           277.453172
# 130       0.633028          35           1786624           455.146421
# 52        0.638285          49           2183936           508.111652
# 5         0.639789          31           5144576           228.090566
# 4         0.642804          30           5144576           410.978220
# 0         0.649304          29           2183936           647.501592
# 22        0.649679          27           1786624           196.698096
# 28        0.652227          30           1456640            98.942470
# 26        0.658142          24           4092416            86.333950
# 42        0.660895          43           5012992           279.152591
# 85        0.661306          42           5144576           156.441548
# 41        0.665117          20           1786624           160.821021
# 18        0.667102          33           2183936           202.891365
# 88        0.669522          28           1456640           175.014941
# 51        0.669597          35           1456640           397.635934
# 132       0.670576          31           1786624           117.875541
# 134       0.671415          36           1787392           552.916143
# 7         0.672500          30           1720576           223.567608
# 79        0.674369          24           1787392           237.604014
# 86        0.674386          49           2183936           495.631126
# 129       0.675609          25           5012992           107.288666
# 80        0.677315          39           5144576           140.306927
# 56        0.679831          16           1720576           251.840994
# 118       0.681615          30           1456640            98.772722
# 27        0.682072          16           1720576            74.711381
# 92        0.684132          40           1456640           423.484179
# 123       0.685502          51           5012992           180.145144
# 113       0.685559          50           4092416           541.266093
# 77        0.688973          30           5144576           407.499570
# 67        0.695254          21           1787392           392.227739
# 115       0.695470          15           1456640           115.888641
# 131       0.697734          13           1720576           128.645660
# 10        0.699970          43           1787392           349.580731
# 65        0.700135          25           1787392           126.268225
# 107       0.700781          46           2183936           252.360932
# 141       0.702523          14           5012992           241.982054
# 29        0.702949          37           1720576           132.271492
# 72        0.706873          53           4092416           287.133655
# 89        0.710463          16           1786624           253.737674
# 12        0.716919          32           1720576           413.420799
# 119       0.719139          30           3960832           359.556009
# 108       0.719295          29           3960832            97.329336
# 83        0.719848          51           1456640           546.008090

# %%
subdf = get_top_performers(df, n_top=50)[varying_attrs]
# for each columns, rename the column by splitting the column name by "." and taking the last element
subdf.columns = subdf.columns.str.split(".").str[-1]
print(df["timing.total_training_time"].mean())
subdf
# Out:
# 1337.4601537305482
#      learning_rate  batch_size  hidden_dim  n_layers  embedding_dim  \
# 103         0.0005          32         128         3            768
# 93          0.0005          16         128         2            512
# 159         0.0010          32         128         3            768
# 8           0.0020          32         128         2            768
# 140         0.0010          16         128         3            512
# 208         0.0020          32         128         3            768
# 60          0.0010          64         128         3            768
# 13          0.0020          64         128         3            768
# 70          0.0005          16         128         3            512
# 134         0.0005          32         128         2            512
# 240         0.0005          64         128         3            512
# 216         0.0020          16         128         3           1024
# 66          0.0020          32         128         2           1024
# 81          0.0005          16         128         2            768
# 9           0.0010          64         128         2           1024
# 88          0.0005          16         128         2           1024
# 197         0.0005          64         128         2            768
# 95          0.0010          16         128         2           1024
# 100         0.0010          64         128         3            512
# 190         0.0010          32         128         2            768
# 59          0.0010          64         128         2            512
# 130         0.0020          32         128         1            512
# 31          0.0020          32         128         3           1024
# 166         0.0020          64         128         2            512
# 19          0.0005          64         128         3           1024
# 127         0.0020          64         256         3            768
# 214         0.0010          16         128         3           1024
# 182         0.0005          16         128         1            768
# 99          0.0005          64         128         1            512
# 230         0.0010          16         256         2            512
# 207         0.0020          64         256         3            512
# 219         0.0010          64         128         3           1024
# 63          0.0005          32         128         3           1024
# 117         0.0005          16         256         2            512
# 150         0.0010          64         512         2            768
# 233         0.0020          32         128         1           1024
# 124         0.0005          16         128         1            512
# 162         0.0010          32         128         1           1024
# 234         0.0020          16         128         1           1024
# 49          0.0020          32         256         3           1024
# 231         0.0010          16         128         1            768
# 52          0.0020          64         512         1           1024
# 53          0.0010          32         128         1            512
# 224         0.0020          32         128         1            768
# 183         0.0020          64         512         3            512
# 74          0.0005          16         256         3           1024
# 135         0.0005          32         256         3            768
# 15          0.0005          16         256         3            512
# 26          0.0010          32         128         1            768
# 29          0.0010          64         256         2            512
#
#     encoder_type  best_val_loss  best_epoch  trainable_params  \
# 103       resnet       0.557982          22           1786624
# 93        resnet       0.587169          12           1456640
# 159       resnet       0.587219          26           1786624
# 8         resnet       0.597611          20           1522688
# 140       resnet       0.599469          15           1720576
# 208       resnet       0.600545          18           1786624
# 60        resnet       0.606082          19           1786624
# 13        resnet       0.609815          19           1786624
# 70        resnet       0.613956          21           1720576
# 134       resnet       0.615399          19           1456640
# 240       resnet       0.620137          17           1720576
# 216       resnet       0.620324          17           1852672
# 66        resnet       0.622877          14           1588736
# 81        resnet       0.622903          18           1522688
# 9         resnet       0.624725          22           1588736
# 88        resnet       0.626822          38           1588736
# 197       resnet       0.628294          24           1522688
# 95        resnet       0.628556          30           1588736
# 100       resnet       0.630354          12           1720576
# 190       resnet       0.634378          26           1522688
# 59        resnet       0.635852          19           1456640
# 130       resnet       0.638166          14           1192704
# 31        resnet       0.639678          29           1852672
# 166       resnet       0.639967           6           1456640
# 19        resnet       0.643693          24           1852672
# 127       resnet       0.644637          19           5144576
# 214       resnet       0.644804          24           1852672
# 182       resnet       0.648922          23           1258752
# 99        resnet       0.650476          17           1192704
# 230       resnet       0.651732           7           3960832
# 207       resnet       0.652357          13           5012992
# 219       resnet       0.653489          35           1852672
# 63        resnet       0.653943          26           1852672
# 117  transformer       0.657409          25           3424256
# 150       resnet       0.658704          31          12377600
# 233       resnet       0.659307          25           1324800
# 124       resnet       0.660021          11           1192704
# 162       resnet       0.660695          25           1324800
# 234       resnet       0.661043          18           1324800
# 49        resnet       0.665550          14           5276160
# 231       resnet       0.665693          17           1258752
# 52        resnet       0.668016          15           8438784
# 53        resnet       0.668930          11           1192704
# 224       resnet       0.669260          17           1258752
# 183       resnet       0.672008          16          16316416
# 74        resnet       0.675367          25           5276160
# 135       resnet       0.677016          39           5144576
# 15        resnet       0.677691          19           5012992
# 26        resnet       0.678893          19           1258752
# 29   transformer       0.679287          29           3424256
#
#      total_training_time
# 103           163.355129
# 93            186.576825
# 159           184.272935
# 8             130.433543
# 140           235.107724
# 208           141.245694
# 60             82.277069
# 13             82.040200
# 70            289.996779
# 134           126.665806
# 240            75.524767
# 216           254.046974
# 66            105.240969
# 81            232.543447
# 9              78.891882
# 88            397.800713
# 197            81.641410
# 95            333.098819
# 100            63.388873
# 190           160.434839
# 59             70.242216
# 130            90.222169
# 31            199.762845
# 166            39.461434
# 19             95.934246
# 127            80.430752
# 214           320.512583
# 182           227.806768
# 99             57.595690
# 230           144.459532
# 207            65.537904
# 219           124.673061
# 63            182.125103
# 117          3460.781258
# 150           100.187830
# 233           130.278728
# 124           148.136339
# 162           124.430980
# 234           195.410317
# 49            122.525121
# 231           189.607934
# 52             54.071301
# 53             80.859360
# 224            98.047855
# 183            72.545958
# 74            330.140887
# 135           245.275980
# 15            277.894889
# 26            108.817444
# 29           3774.087920

# %%
"pkd_pred"[1:]
# Out:
# 'kd_pred'
